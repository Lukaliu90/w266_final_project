# %% [markdown]
# # W266 Final Project - Evaluating LED and Baselines
#
# **Description:**
#
# - This notebook attempts to evaluate the performance of (a) the 2 LED off-the-shelf checkpoints at 2 input length settings; (b) the 40 LED-Base-16384 checkpoints generated after 2 epochs of 20 checkpoints each finetuning on the X-Science dataset; and (c) the baseline of just copying the first X tokens/sentences of the first abstract (i.e. input document).
# - In the process, an additional scoring mechansim is added by using rouge-Lto score the percentage of words in the summary that are copied from the first asbstract, which is used beside the usual rouge-scores
# - The idea behind is that for a multi-document summarization task, just copying from the first abstract will likely mean a lack of capability to take into account the information in the other documents.

# %% [markdown]
# ## Setup

# %%
import evaluate
from pprint import pprint

## General plotting
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

## Managing memory
import gc
import pickle

## Text processing
import re
import numpy as np
from scipy import stats as st

# %%
from datasets import load_dataset, load_metric

# %%
## Checking if GPU is available when running locally
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()
# Out:
# Using device: cuda

# %%
## Loading rouge
rouge = load_metric("rouge")
# Out:
# C:\Users\JustinTo\AppData\Local\Temp\ipykernel_30940\4286193646.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# Using the latest cached version of the module from C:\Users\JustinTo\.cache\huggingface\modules\datasets_modules\metrics\rouge\0ffdb60f436bdb8884d5e4d608d53dbe108e82dac4f494a66f80ef3f647c104f (last modified on Sat Mar 11 13:07:34 2023) since it couldn't be found locally at rouge, or remotely on the Hugging Face Hub.

# %% [markdown]
# # 1. Loading X-Science Dataset (Test Set only)

# %% [markdown]
# ## 2.1 Loading the dataset

# %%
## Loading the dataset
xsci_test = load_dataset('multi_x_science_sum', split='test')

## For text processing as X-Science have not concatenated the source articles
DOC_SEP = "|||||"
# Out:
# Using the latest cached version of the module from C:\Users\JustinTo\.cache\huggingface\modules\datasets_modules\datasets\multi_x_science_sum\2876ec0401f8f5c5acf7f4857dbc8d6229a390ab428321ab848f03f14b7f9729 (last modified on Mon Mar 13 14:43:54 2023) since it couldn't be found locally at multi_x_science_sum., or remotely on the Hugging Face Hub.
# Found cached dataset multi_x_science_sum (C:/Users/JustinTo/.cache/huggingface/datasets/multi_x_science_sum/default/1.1.0/2876ec0401f8f5c5acf7f4857dbc8d6229a390ab428321ab848f03f14b7f9729)

# %% [markdown]
# ## 2.2 Preprocessing

# %% [markdown]
# - Tokenization is not necessary as all the answers from models/baseline to be compared to the test labels are already in text form.
# - So, we only need to pre-process the X-Science dataset labels to the form we want, e.g. changing the citation numbers to @cite, etc.

# %%
pat = re.compile("@cite_[0-9]+")

# %%
def preprocess_dataset(example):
    output = {}
    output["abstracts"] = (
        example["abstract"].split("| Abstract: ")[-1]
        + DOC_SEP
        + DOC_SEP.join([x for x in example["ref_abstract"]["abstract"] if x])
    )
    output["related_work"] = pat.sub("@cite", example["related_work"])
    
    return output

# %%
def preprocess_dataset_batched(example):
    output = {}
    output["abstracts"] = []
    output["related_work"] = []
    output["main_article"] = []
    
    for abstract, ref_abstract in zip(
        example["abstract"], example["ref_abstract"]
    ):
        output["abstracts"].append(
            abstract.split("| Abstract: ")[-1]
            + DOC_SEP
            + DOC_SEP.join([x for x in ref_abstract["abstract"] if x])
        )
        
        # Main article added for calculating the degree of copying
        output["main_article"].append(abstract)
        
    for related_work in example["related_work"]:
        output["related_work"].append(pat.sub("@cite", related_work))
    
    return output

# %%
xsci_test_processed = xsci_test.map(
    # preprocess_dataset,
    preprocess_dataset_batched,
    remove_columns=xsci_test.column_names,
    batched=True,
    batch_size=1,
    )
# Out:
#   0%|          | 0/5093 [00:00<?, ?ba/s]

# %% [markdown]
# # 2. Baseline LED Results

# %% [markdown]
# ## 2.1 Off-the-shelf Large Checkpoint ("LED-base-16384-arxiv")

# %% [markdown]
# ### 2.1.1 Long Input Sequence Length (16384) & Sample Answers

# %%
## Loading pickled results
with open("answers_revised/baselines/LED_large_16384tokens.pkl", "rb") as f:
    answers_exp1 = pickle.load(f)

# %%
## Calculating the rouge score
metric_exp1 = rouge.compute(predictions=answers_exp1,
                            references=[ref for ref in xsci_test_processed['related_work']],
                            use_stemmer = True)

copying_metric_exp1 = rouge.compute(predictions=answers_exp1,
                                    references=[ref for ref in xsci_test_processed['main_article']],
                                    use_stemmer = True)

# %%
metric_exp1
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.2909941324368112, recall=0.35105082313707636, fmeasure=0.30077302726714655), mid=Score(precision=0.2942472156556126, recall=0.35374213462422277, fmeasure=0.3030829300045328), high=Score(precision=0.2970721131079737, recall=0.356640422810119, fmeasure=0.3052169281154026)),
#  'rouge2': AggregateScore(low=Score(precision=0.05114039705929173, recall=0.061469198630368205, fmeasure=0.05257839595270015), mid=Score(precision=0.05250657974529506, recall=0.06306549953449214, fmeasure=0.05394162344303733), high=Score(precision=0.053884108434255444, recall=0.06468015800210036, fmeasure=0.05522453940119105)),
#  'rougeL': AggregateScore(low=Score(precision=0.14947553643070308, recall=0.18391832303844824, fmeasure=0.15527962272327), mid=Score(precision=0.15112890755384387, recall=0.18579472374569955, fmeasure=0.1565722710198794), high=Score(precision=0.15275375825054335, recall=0.18756221498065537, fmeasure=0.15778411072390058)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.18740727574694538, recall=0.2306709155336622, fmeasure=0.1950048387260551), mid=Score(precision=0.18922998709749517, recall=0.23279784742602366, fmeasure=0.1964420871269737), high=Score(precision=0.19112639413345217, recall=0.23489393080714166, fmeasure=0.19794637524088468))}

# %%
copying_metric_exp1
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.5804809712983097, recall=0.43098446626073994, fmeasure=0.4795182335301225), mid=Score(precision=0.5866903800577534, recall=0.4363999019267688, fmeasure=0.4848281946091112), high=Score(precision=0.5929851958465849, recall=0.441824876210364, fmeasure=0.49040639901921956)),
#  'rouge2': AggregateScore(low=Score(precision=0.3632678438094504, recall=0.2677063043309678, fmeasure=0.2989803918609445), mid=Score(precision=0.3732204090197948, recall=0.27503091164081683, fmeasure=0.307423927697038), high=Score(precision=0.38266863048879474, recall=0.28216887324677353, fmeasure=0.3151152944739423)),
#  'rougeL': AggregateScore(low=Score(precision=0.445590154977894, recall=0.32988122718600327, fmeasure=0.36738107006177745), mid=Score(precision=0.45340047127281485, recall=0.3360586042185112, fmeasure=0.37402672650395546), high=Score(precision=0.4613234726241873, recall=0.3420236033778624, fmeasure=0.38022869054501984)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.47263562117492014, recall=0.35063103377366783, fmeasure=0.3901323471433934), mid=Score(precision=0.4799257145410758, recall=0.3564375579865867, fmeasure=0.39626732853153923), high=Score(precision=0.48731958530846164, recall=0.3620434870697027, fmeasure=0.4024014762450131))}

# %%
answers_exp1[0]
# Out:
# " in multi-agent environments, an intelligent agent often needs to interact with other individuals or groups of agents to achieve its goals. agent tracking is one key capability required for intelligent interaction. \n it involves monitoring the observable actions of other agents and inferring their unobserved actions, plans, goals and behaviors. \n this article examines the implications of such an agent tracking capability for agent architectures. it specifically focuses on real-time and dynamic environments, where an intelligent agent is faced with the challenge of tracking the highly flexible mix of goal-driven and reactive behaviors of other agents, in real-time. \n the key implication is that an agent architecture needs to provide direct support for flexible and efficient reasoning about other agents' models. in this article, such support takes the form of an architectural capability to execute the other agent s models, enabling mental simulation of their behaviors. \n other architectural requirements that follow include the capabilities for (pseudo-) simultaneous execution of multiple agent models, dynamic sharing and"

# %% [markdown]
# ### 2.1.2 Short Input Sequence Length (1024) & Sample Answers

# %%
## Loading pickled results
with open("answers_revised/baselines/LED_large_1024tokens.pkl", "rb") as f:
    answers_exp2 = pickle.load(f)

# %%
## Calculating the rouge score
metric_exp2 = rouge.compute(predictions=answers_exp2,
                            references=[ref for ref in xsci_test_processed['related_work']],
                            use_stemmer = True)

copying_metric_exp2 = rouge.compute(predictions=answers_exp2,
                                    references=[ref for ref in xsci_test_processed['main_article']],
                                    use_stemmer = True)

# %%
metric_exp2
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.29202173734823894, recall=0.3476110916538046, fmeasure=0.29941398786584933), mid=Score(precision=0.29515888545413427, recall=0.3503062240451726, fmeasure=0.3017650577927991), high=Score(precision=0.29811998899916725, recall=0.3531599191621091, fmeasure=0.3039226750095273)),
#  'rouge2': AggregateScore(low=Score(precision=0.05109327022756113, recall=0.06064176630880606, fmeasure=0.05217138520824604), mid=Score(precision=0.05252993312220889, recall=0.062282521667073425, fmeasure=0.053504252967343895), high=Score(precision=0.05392380879732633, recall=0.06392864814481376, fmeasure=0.05484064290952403)),
#  'rougeL': AggregateScore(low=Score(precision=0.1503566582559145, recall=0.18257182819385767, fmeasure=0.1550218335890702), mid=Score(precision=0.1520194357783777, recall=0.18445279412278887, fmeasure=0.15626907514442895), high=Score(precision=0.1535550065693761, recall=0.1862921612922484, fmeasure=0.15741066865253625)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.18811547147122426, recall=0.2284913027271293, fmeasure=0.19434638602697843), mid=Score(precision=0.1899922484081949, recall=0.23077994830558657, fmeasure=0.1957197049148841), high=Score(precision=0.191897850976959, recall=0.2328429626888323, fmeasure=0.19704985197844244))}

# %%
copying_metric_exp2
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.5946941944928145, recall=0.4360596677977077, fmeasure=0.4877595209953568), mid=Score(precision=0.6011510151203083, recall=0.44168158913879896, fmeasure=0.49339745494004583), high=Score(precision=0.6074880685655073, recall=0.4471351026036722, fmeasure=0.49838492081865404)),
#  'rouge2': AggregateScore(low=Score(precision=0.38500089632351125, recall=0.2806171160843172, fmeasure=0.3152320162216887), mid=Score(precision=0.39451993949593006, recall=0.2873483711825244, fmeasure=0.32274421092300376), high=Score(precision=0.4040176116807798, recall=0.2948062312139038, fmeasure=0.33067826858405786)),
#  'rougeL': AggregateScore(low=Score(precision=0.4635350151715852, recall=0.33911062747048365, fmeasure=0.379926475297668), mid=Score(precision=0.4716740579323859, recall=0.3454384618777596, fmeasure=0.38650097915044423), high=Score(precision=0.47946183157903216, recall=0.3516316762927688, fmeasure=0.39324304836801555)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.4896710128468856, recall=0.358951427320717, fmeasure=0.4017749752435556), mid=Score(precision=0.49711706833870895, recall=0.36488489597436635, fmeasure=0.4077922416661817), high=Score(precision=0.5048152800071393, recall=0.37088079099906074, fmeasure=0.41396254463860105))}

# %%
answers_exp2[0]
# Out:
# ' we present our approach to the problem of how an agent, within an economic Multi-Agent System, can determine when it should behave strategically (i.e. learn and use models of other agents ), and when it should act as a simple price-taker. we provide a framework for the incremental implementation of modeling capabilities in agents, and a description of the forms of knowledge required. \n we have implemented an agent architecture, an experimental variant of the soar integrated architecture, that conforms to all of these requirements. \n agents based on this architecture have been implemented to execute two different tasks in a real-time, dynamic, multi-agent domain. \n the agents were implemented and different populations simulated in order to learn more about their behavior and the merits of using and learning agent models. \n our results show, among other lessons, how savvy buyers can avoid being cheated by sellers, how price volatility can be used to quantitatively predict the benefits of deeper models, and how'

# %% [markdown]
# ## 2.2 Off-the-shelf Base Checkpoint ("LED-base-16384")

# %% [markdown]
# ### 2.2.1 Long Input Sequence Length (16384) & Sample Answers

# %%
## Loading pickled results
with open("answers_revised/baselines/LED_base_16384tokens.pkl", "rb") as f:
    answers_exp3 = pickle.load(f)

# %%
## Calculating the rouge score
metric_exp3 = rouge.compute(predictions=answers_exp3,
                            references=[ref for ref in xsci_test_processed['related_work']],
                            use_stemmer = True)

copying_metric_exp3 = rouge.compute(predictions=answers_exp3,
                                    references=[ref for ref in xsci_test_processed['main_article']],
                                    use_stemmer = True)

# %%
metric_exp3
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.25830633435027256, recall=0.3968438262683915, fmeasure=0.29700336313124903), mid=Score(precision=0.26126087743485504, recall=0.399375050558616, fmeasure=0.29940693690755715), high=Score(precision=0.26391486209433423, recall=0.4020188104898597, fmeasure=0.30166923811178403)),
#  'rouge2': AggregateScore(low=Score(precision=0.04430336443409369, recall=0.06852074159341255, fmeasure=0.051092768490646624), mid=Score(precision=0.045255209888487094, recall=0.06988058539713318, fmeasure=0.0520976031529633), high=Score(precision=0.04614715675220126, recall=0.07132512576368692, fmeasure=0.05302513627299239)),
#  'rougeL': AggregateScore(low=Score(precision=0.12799178381235296, recall=0.20292193492404648, fmeasure=0.14819555110490149), mid=Score(precision=0.1292496808406487, recall=0.2046865870656942, fmeasure=0.14914610839134823), high=Score(precision=0.13045063779179358, recall=0.20638772726265217, fmeasure=0.1502112805002533)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.12803781350866575, recall=0.20283927688927084, fmeasure=0.14823408980234948), mid=Score(precision=0.1292229190391374, recall=0.20460957330202445, fmeasure=0.14915125920970407), high=Score(precision=0.13048298295903055, recall=0.2065187883484496, fmeasure=0.15012346983353742))}

# %%
copying_metric_exp3
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.795455328386271, recall=0.775267100188124, fmeasure=0.7635032226541796), mid=Score(precision=0.8012543025205973, recall=0.7815542031014585, fmeasure=0.769430494044121), high=Score(precision=0.8068480324379127, recall=0.7887987480599074, fmeasure=0.7752297877709678)),
#  'rouge2': AggregateScore(low=Score(precision=0.7364697647471133, recall=0.7284697152197072, fmeasure=0.7139075466914486), mid=Score(precision=0.7448441298601729, recall=0.7368793284311195, fmeasure=0.7217796335805167), high=Score(precision=0.752990380210822, recall=0.7459295677570408, fmeasure=0.7300286198202143)),
#  'rougeL': AggregateScore(low=Score(precision=0.7608502160313695, recall=0.7474052789074276, fmeasure=0.7339103361154311), mid=Score(precision=0.7686121547499548, recall=0.7553827136959743, fmeasure=0.7414086776059847), high=Score(precision=0.776300493132067, recall=0.7623542609378742, fmeasure=0.7483180357351624)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.7612831840506866, recall=0.7473781586148852, fmeasure=0.7342364244396371), mid=Score(precision=0.7686578932579506, recall=0.7553658107919008, fmeasure=0.741460528517), high=Score(precision=0.7758280124941157, recall=0.7631675618640641, fmeasure=0.7484441762912848))}

# %%
answers_exp3[0]
# Out:
# "We present our approach to the problem of how an agent, within an economic Multi-Agent System, can determine when it should behave strategically (i.e. learn and use models of other agents), and when it should act as a simple price-taker. We provide a framework for the incremental implementation of modeling capabilities in agents, and a description of the forms of knowledge required. The agents were implemented and different populations simulated in order to learn more about their behavior and the merits of using and learning agent models. Our results show, among other lessons, how savvy buyers can avoid being cheated'' by sellers, how price volatility can be used to quantitatively predict the benefits of deeper models, and how specific types of agent populations influence system behavior.|||||In multi-agent environments, an intelligent agent often needs to interact with other individuals or groups of agents to achieve its goals. Agent tracking is one key capability required for intelligent interaction. It involves monitoring the observable actions of other agents and inferring"

# %% [markdown]
# ### 2.2.2 Short Input Sequence Length (1024) & Sample Answers

# %%
## Loading pickled results
with open("answers_revised/baselines/LED_base_1024tokens.pkl", "rb") as f:
    answers_exp4 = pickle.load(f)

# %%
## Calculating the rouge score
metric_exp4 = rouge.compute(predictions=answers_exp4,
                            references=[ref for ref in xsci_test_processed['related_work']],
                            use_stemmer = True)

copying_metric_exp4 = rouge.compute(predictions=answers_exp4,
                                    references=[ref for ref in xsci_test_processed['main_article']],
                                    use_stemmer = True)

# %%
metric_exp4
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.25830633435027256, recall=0.3968438262683915, fmeasure=0.29700336313124903), mid=Score(precision=0.26126087743485504, recall=0.399375050558616, fmeasure=0.29940693690755715), high=Score(precision=0.26391486209433423, recall=0.4020188104898597, fmeasure=0.30166923811178403)),
#  'rouge2': AggregateScore(low=Score(precision=0.04430336443409369, recall=0.06852074159341255, fmeasure=0.051092768490646624), mid=Score(precision=0.045255209888487094, recall=0.06988058539713318, fmeasure=0.0520976031529633), high=Score(precision=0.04614715675220126, recall=0.07132512576368692, fmeasure=0.05302513627299239)),
#  'rougeL': AggregateScore(low=Score(precision=0.12799178381235296, recall=0.20292193492404648, fmeasure=0.14819555110490149), mid=Score(precision=0.1292496808406487, recall=0.2046865870656942, fmeasure=0.14914610839134823), high=Score(precision=0.13045063779179358, recall=0.20638772726265217, fmeasure=0.1502112805002533)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.12803781350866575, recall=0.20283927688927084, fmeasure=0.14823408980234948), mid=Score(precision=0.1292229190391374, recall=0.20460957330202445, fmeasure=0.14915125920970407), high=Score(precision=0.13048298295903055, recall=0.2065187883484496, fmeasure=0.15012346983353742))}

# %%
copying_metric_exp4
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.795455328386271, recall=0.775267100188124, fmeasure=0.7635032226541796), mid=Score(precision=0.8012543025205973, recall=0.7815542031014585, fmeasure=0.769430494044121), high=Score(precision=0.8068480324379127, recall=0.7887987480599074, fmeasure=0.7752297877709678)),
#  'rouge2': AggregateScore(low=Score(precision=0.7364697647471133, recall=0.7284697152197072, fmeasure=0.7139075466914486), mid=Score(precision=0.7448441298601729, recall=0.7368793284311195, fmeasure=0.7217796335805167), high=Score(precision=0.752990380210822, recall=0.7459295677570408, fmeasure=0.7300286198202143)),
#  'rougeL': AggregateScore(low=Score(precision=0.7608502160313695, recall=0.7474052789074276, fmeasure=0.7339103361154311), mid=Score(precision=0.7686121547499548, recall=0.7553827136959743, fmeasure=0.7414086776059847), high=Score(precision=0.776300493132067, recall=0.7623542609378742, fmeasure=0.7483180357351624)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.7612831840506866, recall=0.7473781586148852, fmeasure=0.7342364244396371), mid=Score(precision=0.7686578932579506, recall=0.7553658107919008, fmeasure=0.741460528517), high=Score(precision=0.7758280124941157, recall=0.7631675618640641, fmeasure=0.7484441762912848))}

# %%
answers_exp4[0]
# Out:
# "We present our approach to the problem of how an agent, within an economic Multi-Agent System, can determine when it should behave strategically (i.e. learn and use models of other agents), and when it should act as a simple price-taker. We provide a framework for the incremental implementation of modeling capabilities in agents, and a description of the forms of knowledge required. The agents were implemented and different populations simulated in order to learn more about their behavior and the merits of using and learning agent models. Our results show, among other lessons, how savvy buyers can avoid being cheated'' by sellers, how price volatility can be used to quantitatively predict the benefits of deeper models, and how specific types of agent populations influence system behavior.|||||In multi-agent environments, an intelligent agent often needs to interact with other individuals or groups of agents to achieve its goals. Agent tracking is one key capability required for intelligent interaction. It involves monitoring the observable actions of other agents and inferring"

# %% [markdown]
# # 3. Finetuned LED-Models

# %% [markdown]
# ## 3.1 Compiling results

# %%
## Results are available for Epochs 1 and 2, Runs 5, 10, 15 and 20

model_list = [(epoch, num) for epoch in [1,2] for num in [5, 10, 15, 20]]

answers_tunedLED = {}
metric_tunedLED = {}
copying_metric_tunedLED = {}

for (epoch, num) in model_list:
    PATH = f"answers_revised/epoch{epoch}/LED_xsci_finetuned_run{num}.pkl"
    with open(PATH, "rb") as f:
        answers_tunedLED[(epoch, num)] = pickle.load(f)
    
for (key, value) in answers_tunedLED.items():
    metric_tunedLED[key] = rouge.compute(predictions=value,
                           references=[ref for ref in xsci_test_processed['related_work']],
                           use_stemmer = True)
        
    copying_metric_tunedLED[key] = rouge.compute(predictions=value,
                                                 references=[ref for ref in xsci_test_processed['main_article']],
                                                 use_stemmer = True)

# %%
metric_tunedLED.keys()
# Out:
# dict_keys([(1, 5), (1, 10), (1, 15), (1, 20), (2, 5), (2, 10), (2, 15), (2, 20)])

# %%
for (key, value) in metric_tunedLED.items():
    print(f"\n-----Results for Epoch {key[0]} Run {key[1]} Tuned LED Model-----")
    for (name, figures) in value.items():
        print(name.capitalize())
        print(figures)
# Out:
# -----Results for Epoch 1 Run 5 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.43096455287873037, recall=0.25111143174866973, fmeasure=0.298003255363893), mid=Score(precision=0.43512150987668774, recall=0.25362619435654454, fmeasure=0.30009905518756474), high=Score(precision=0.4388452341964497, recall=0.256417712889918, fmeasure=0.30224150244925657))
# Rouge2
# AggregateScore(low=Score(precision=0.08980536975033572, recall=0.05144090068252852, fmeasure=0.06117450713194414), mid=Score(precision=0.09171552038463286, recall=0.052573429410541925, fmeasure=0.062397025605467275), high=Score(precision=0.09374341221858144, recall=0.05379855034876872, fmeasure=0.06368920883418691))
# Rougel
# AggregateScore(low=Score(precision=0.25305664450449245, recall=0.14679973063146354, fmeasure=0.17391009204917518), mid=Score(precision=0.25543295003753413, recall=0.14843453471314955, fmeasure=0.1751987240474616), high=Score(precision=0.2579235219950028, recall=0.15012688752823256, fmeasure=0.17654005974377837))
# Rougelsum
# AggregateScore(low=Score(precision=0.252975719183781, recall=0.1468225980951824, fmeasure=0.17400431270834676), mid=Score(precision=0.25553653887435757, recall=0.1484388810727406, fmeasure=0.17522411854547298), high=Score(precision=0.25800857040385494, recall=0.15007902797317552, fmeasure=0.17652283602791552))
#
# -----Results for Epoch 1 Run 10 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.4110164710351228, recall=0.2619571766164502, fmeasure=0.3004206002987904), mid=Score(precision=0.41515216884398276, recall=0.2648749341198421, fmeasure=0.3028057274214866), high=Score(precision=0.4187318207823053, recall=0.26789249199796894, fmeasure=0.30501871744598325))
# Rouge2
# AggregateScore(low=Score(precision=0.0843371900716375, recall=0.0529773984178791, fmeasure=0.06094458192541518), mid=Score(precision=0.08629559082939277, recall=0.05424070881716704, fmeasure=0.06217327185026891), high=Score(precision=0.08828298388812306, recall=0.05566035396302648, fmeasure=0.06363111833923878))
# Rougel
# AggregateScore(low=Score(precision=0.23714137345811473, recall=0.15079554757341188, fmeasure=0.17244511802364537), mid=Score(precision=0.23954571324289736, recall=0.15257683935705874, fmeasure=0.1739011608240951), high=Score(precision=0.24182298518077974, recall=0.154447193375051, fmeasure=0.17539273413271048))
# Rougelsum
# AggregateScore(low=Score(precision=0.237201692853276, recall=0.1506424438072148, fmeasure=0.1725273655789844), mid=Score(precision=0.23956126738967404, recall=0.15252048167153026, fmeasure=0.1738895205744298), high=Score(precision=0.2419541364909659, recall=0.15428804695959922, fmeasure=0.17527877822892235))
#
# -----Results for Epoch 1 Run 15 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.42169889184981746, recall=0.2611293932885375, fmeasure=0.30257347374421556), mid=Score(precision=0.42549226447668886, recall=0.26382086148233264, fmeasure=0.30487692329488325), high=Score(precision=0.42893131345700153, recall=0.26638912423416666, fmeasure=0.3069535705145013))
# Rouge2
# AggregateScore(low=Score(precision=0.08707679857279337, recall=0.05280928646370531, fmeasure=0.06143826268329009), mid=Score(precision=0.0891876197067181, recall=0.05405843263114421, fmeasure=0.06280024333214988), high=Score(precision=0.09131609942250032, recall=0.055394084075119525, fmeasure=0.06418577449052765))
# Rougel
# AggregateScore(low=Score(precision=0.2443970796668389, recall=0.15054096129225708, fmeasure=0.1742211021441864), mid=Score(precision=0.24678329398697973, recall=0.15220982238092634, fmeasure=0.1755638628730346), high=Score(precision=0.24941155003135698, recall=0.15411180299977834, fmeasure=0.17706033116485914))
# Rougelsum
# AggregateScore(low=Score(precision=0.2444243793709559, recall=0.15036958662633815, fmeasure=0.1742500416001385), mid=Score(precision=0.24692403392427448, recall=0.1521737780184101, fmeasure=0.17555937912456254), high=Score(precision=0.2493696605152347, recall=0.1538425187316553, fmeasure=0.17699227754811847))
#
# -----Results for Epoch 1 Run 20 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.40809864829216047, recall=0.27548213077995676, fmeasure=0.3088415158101878), mid=Score(precision=0.41197564928912683, recall=0.2784056519077982, fmeasure=0.3111011084357489), high=Score(precision=0.41562468383236095, recall=0.2812082246330546, fmeasure=0.3133897007669812))
# Rouge2
# AggregateScore(low=Score(precision=0.08334483432386015, recall=0.05515590520872173, fmeasure=0.062094845872865144), mid=Score(precision=0.08550319471898944, recall=0.056580316152372453, fmeasure=0.06363971687828035), high=Score(precision=0.08767731268541937, recall=0.0579620286217891, fmeasure=0.06505702080037264))
# Rougel
# AggregateScore(low=Score(precision=0.23338300462013542, recall=0.1562521191727909, fmeasure=0.17515348683937335), mid=Score(precision=0.23570388737707249, recall=0.15812067821972492, fmeasure=0.1765933956250317), high=Score(precision=0.23815549881647938, recall=0.15992439250096788, fmeasure=0.17809629121803053))
# Rougelsum
# AggregateScore(low=Score(precision=0.23341262985171973, recall=0.156361833817513, fmeasure=0.17524571006991257), mid=Score(precision=0.23584044215036715, recall=0.1581083601439218, fmeasure=0.17663513188612928), high=Score(precision=0.23851203903038817, recall=0.15982341515386042, fmeasure=0.17806454394307844))
#
# -----Results for Epoch 2 Run 5 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.4242037604856127, recall=0.26340326474071785, fmeasure=0.305360632266916), mid=Score(precision=0.4284668183259348, recall=0.2660316133672952, fmeasure=0.3076621343992044), high=Score(precision=0.4322981952600353, recall=0.2687883055011459, fmeasure=0.30991377986349034))
# Rouge2
# AggregateScore(low=Score(precision=0.09025239835815452, recall=0.05506690702300346, fmeasure=0.06401519963113848), mid=Score(precision=0.09235604120787877, recall=0.05633897351425521, fmeasure=0.06535729446804031), high=Score(precision=0.09445249245877978, recall=0.0576745866163437, fmeasure=0.06677565095372863))
# Rougel
# AggregateScore(low=Score(precision=0.24600272102444612, recall=0.1515250798552696, fmeasure=0.17566468150789755), mid=Score(precision=0.24824774080990133, recall=0.15315046891747958, fmeasure=0.1769122543811365), high=Score(precision=0.25072268012676346, recall=0.15492678927080278, fmeasure=0.17833996822899176))
# Rougelsum
# AggregateScore(low=Score(precision=0.24586961032554874, recall=0.1514665934086414, fmeasure=0.17561365530667714), mid=Score(precision=0.24837902143467055, recall=0.15306784517289698, fmeasure=0.17690603519539577), high=Score(precision=0.25086408376167335, recall=0.15472001674434666, fmeasure=0.17835469534945805))
#
# -----Results for Epoch 2 Run 10 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.4108159925633304, recall=0.27821093748229014, fmeasure=0.3111815615485406), mid=Score(precision=0.4147901645611401, recall=0.28102745863595113, fmeasure=0.31332139792586644), high=Score(precision=0.4182761248950563, recall=0.284066725459976, fmeasure=0.31552193326839634))
# Rouge2
# AggregateScore(low=Score(precision=0.08564473410663596, recall=0.05741130283906804, fmeasure=0.06419780831962202), mid=Score(precision=0.0876045434860268, recall=0.05884546125040356, fmeasure=0.06569052101607152), high=Score(precision=0.08948615369297577, recall=0.06025958915520987, fmeasure=0.0670936707355061))
# Rougel
# AggregateScore(low=Score(precision=0.23352560140285775, recall=0.15728807546403928, fmeasure=0.17572394505218866), mid=Score(precision=0.23567863571870074, recall=0.15910500461180332, fmeasure=0.17705981511903993), high=Score(precision=0.23797094138574035, recall=0.16099847306249984, fmeasure=0.17854097977554745))
# Rougelsum
# AggregateScore(low=Score(precision=0.23333824957078478, recall=0.1572946851992507, fmeasure=0.17568784083612754), mid=Score(precision=0.23578256859581495, recall=0.15909904807947936, fmeasure=0.1770898253472759), high=Score(precision=0.2383572269484623, recall=0.16084459323031755, fmeasure=0.17852505968689508))
#
# -----Results for Epoch 2 Run 15 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.41818515903400894, recall=0.2808311443317809, fmeasure=0.31473167020505755), mid=Score(precision=0.4223585415111799, recall=0.28371145490004457, fmeasure=0.317119215142852), high=Score(precision=0.4260382204096851, recall=0.286622072621653, fmeasure=0.3192715531356382))
# Rouge2
# AggregateScore(low=Score(precision=0.08745374838718074, recall=0.057884903709231876, fmeasure=0.06504155601223614), mid=Score(precision=0.08956512170623832, recall=0.05941233334075923, fmeasure=0.06660179772217148), high=Score(precision=0.09162072289202579, recall=0.06082046717988752, fmeasure=0.0679399012364955))
# Rougel
# AggregateScore(low=Score(precision=0.2391427208818564, recall=0.15948723023824896, fmeasure=0.17858693226092642), mid=Score(precision=0.2414807321167867, recall=0.16119586433369348, fmeasure=0.1799506530846891), high=Score(precision=0.24406461267831464, recall=0.16318715820225924, fmeasure=0.18148133473446312))
# Rougelsum
# AggregateScore(low=Score(precision=0.23916625822580728, recall=0.15937676452565877, fmeasure=0.17854252775737164), mid=Score(precision=0.2415902566348171, recall=0.16118107721337285, fmeasure=0.17995912865387928), high=Score(precision=0.2439844701616209, recall=0.1629615422994577, fmeasure=0.1814153494072101))
#
# -----Results for Epoch 2 Run 20 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.40303480993985036, recall=0.2909575243840067, fmeasure=0.3160477646779651), mid=Score(precision=0.4069238162085612, recall=0.29391103822587383, fmeasure=0.31844082738882556), high=Score(precision=0.4104875402921589, recall=0.2966363767505928, fmeasure=0.32054324538886475))
# Rouge2
# AggregateScore(low=Score(precision=0.08350633767891098, recall=0.059583443503937586, fmeasure=0.06484318732975203), mid=Score(precision=0.08547358174517058, recall=0.0611121404971496, fmeasure=0.066355800669709), high=Score(precision=0.08757106712501123, recall=0.06261032089511105, fmeasure=0.0679028328312953))
# Rougel
# AggregateScore(low=Score(precision=0.22761562218773013, recall=0.16313262264441084, fmeasure=0.17698018243407926), mid=Score(precision=0.22989849510362498, recall=0.16499375560240076, fmeasure=0.17847465712871818), high=Score(precision=0.23255660907453118, recall=0.1670099210230086, fmeasure=0.17996816203885943))
# Rougelsum
# AggregateScore(low=Score(precision=0.22767360638220785, recall=0.16310986611077002, fmeasure=0.17710876522541286), mid=Score(precision=0.23000972637103104, recall=0.16493584673262018, fmeasure=0.1784702621107675), high=Score(precision=0.23255363225761272, recall=0.16696701475791498, fmeasure=0.17994498574469597))

# %%
for (key, value) in copying_metric_tunedLED.items():
    print(f"\n-----Results for Epoch {key[0]} Run {key[1]} Tuned LED Model-----")
    for (name, figures) in value.items():
        print(name.capitalize())
        print(figures)
# Out:
# -----Results for Epoch 1 Run 5 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.5226669879338464, recall=0.18182631614630482, fmeasure=0.2595916872195215), mid=Score(precision=0.5270972002290121, recall=0.1839541434785873, fmeasure=0.26188062737870965), high=Score(precision=0.5315583041008248, recall=0.18605108802815992, fmeasure=0.2642760697272397))
# Rouge2
# AggregateScore(low=Score(precision=0.1884356754463796, recall=0.06043040244380299, fmeasure=0.08797707849195342), mid=Score(precision=0.19336956242199865, recall=0.06212871641061322, fmeasure=0.0903653409964461), high=Score(precision=0.19838776624664275, recall=0.06369035936031123, fmeasure=0.0924940470829754))
# Rougel
# AggregateScore(low=Score(precision=0.34331872527699303, recall=0.11660297818811133, fmeasure=0.16721704170019797), mid=Score(precision=0.3476666548494963, recall=0.11807125193809927, fmeasure=0.16903793373128517), high=Score(precision=0.3516851683235269, recall=0.1195573144114709, fmeasure=0.17082528198036503))
# Rougelsum
# AggregateScore(low=Score(precision=0.3431743825788452, recall=0.11668536401001636, fmeasure=0.16732336600658115), mid=Score(precision=0.34755290916429793, recall=0.11809322029953714, fmeasure=0.16908831848595077), high=Score(precision=0.35172185352306073, recall=0.11955858247733793, fmeasure=0.17085093301918305))
#
# -----Results for Epoch 1 Run 10 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.5315843591046568, recall=0.20487701476417974, fmeasure=0.28272719577361594), mid=Score(precision=0.5366859032923506, recall=0.2074411314619003, fmeasure=0.2856263567509122), high=Score(precision=0.5417087609085858, recall=0.21013150419322899, fmeasure=0.28863087501991))
# Rouge2
# AggregateScore(low=Score(precision=0.21088586346452923, recall=0.07689180985677349, fmeasure=0.10764307504125406), mid=Score(precision=0.21676494236668364, recall=0.07911006100595179, fmeasure=0.11050172631703148), high=Score(precision=0.22255851444009683, recall=0.08128686279535213, fmeasure=0.11339685251001926))
# Rougel
# AggregateScore(low=Score(precision=0.3512265635574521, recall=0.13239127725462763, fmeasure=0.18371960855267105), mid=Score(precision=0.3565266262839203, recall=0.13444465726673738, fmeasure=0.18605412996206588), high=Score(precision=0.3615038272790689, recall=0.13658898513818257, fmeasure=0.18860062171993308))
# Rougelsum
# AggregateScore(low=Score(precision=0.35177380651271906, recall=0.13242266830214036, fmeasure=0.1835007699727174), mid=Score(precision=0.356331805421653, recall=0.13443312097559051, fmeasure=0.18607268858813159), high=Score(precision=0.36179705654364824, recall=0.1365465115643028, fmeasure=0.1886019101370957))
#
# -----Results for Epoch 1 Run 15 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.4968894312543547, recall=0.18573250690696486, fmeasure=0.25818141041527937), mid=Score(precision=0.5015381146647642, recall=0.1880724251403531, fmeasure=0.2606880718457897), high=Score(precision=0.5058848920355472, recall=0.19012574362766577, fmeasure=0.26303685142309596))
# Rouge2
# AggregateScore(low=Score(precision=0.1537064158927373, recall=0.05267074127148437, fmeasure=0.07467467108497712), mid=Score(precision=0.15830649019132503, recall=0.054167071238782484, fmeasure=0.07671712516528839), high=Score(precision=0.16251292410742962, recall=0.05569693402595853, fmeasure=0.07879818812430683))
# Rougel
# AggregateScore(low=Score(precision=0.3178488213350171, recall=0.11510266717884407, fmeasure=0.1610454899972555), mid=Score(precision=0.321436572740383, recall=0.1166029278281951, fmeasure=0.16277953741418472), high=Score(precision=0.3253368995654695, recall=0.11810918297142692, fmeasure=0.1644900322064518))
# Rougelsum
# AggregateScore(low=Score(precision=0.31747889873075424, recall=0.11513165860179224, fmeasure=0.1609500742009652), mid=Score(precision=0.3215047125223919, recall=0.11662876722513016, fmeasure=0.16278141507530025), high=Score(precision=0.3256165140837414, recall=0.11818964718234305, fmeasure=0.16471501695935334))
#
# -----Results for Epoch 1 Run 20 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.4841191243492036, recall=0.1988249976804925, fmeasure=0.26772003068060574), mid=Score(precision=0.48840166096487914, recall=0.20133592836646752, fmeasure=0.27028197340591903), high=Score(precision=0.49290017245742235, recall=0.2037852187038735, fmeasure=0.2727379762028637))
# Rouge2
# AggregateScore(low=Score(precision=0.14733045717258728, recall=0.056973757564406056, fmeasure=0.07776802038364651), mid=Score(precision=0.15187840625873222, recall=0.05872126793684379, fmeasure=0.07995553472177985), high=Score(precision=0.15649294542300257, recall=0.060538963253705405, fmeasure=0.0822889034194919))
# Rougel
# AggregateScore(low=Score(precision=0.30312441710638677, recall=0.12137448227241107, fmeasure=0.16437830232021575), mid=Score(precision=0.3070672436560429, recall=0.12297148926342025, fmeasure=0.16613042020559304), high=Score(precision=0.31118850670654646, recall=0.12480136058258808, fmeasure=0.1681461676180789))
# Rougelsum
# AggregateScore(low=Score(precision=0.3033473287557141, recall=0.12130484053074651, fmeasure=0.16420972818920793), mid=Score(precision=0.3071691248733256, recall=0.12302939617834568, fmeasure=0.16617705302763713), high=Score(precision=0.3111745189697916, recall=0.12475100687634812, fmeasure=0.16823952505324252))
#
# -----Results for Epoch 2 Run 5 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.5255789319877798, recall=0.19765604878525406, fmeasure=0.2741441764888292), mid=Score(precision=0.5301820907325945, recall=0.20002467958688247, fmeasure=0.2767642910678486), high=Score(precision=0.5348695803784447, recall=0.20253835536692633, fmeasure=0.2794855528979327))
# Rouge2
# AggregateScore(low=Score(precision=0.19158114333681198, recall=0.06744970353558127, fmeasure=0.09497326155338899), mid=Score(precision=0.19690623321870493, recall=0.0692996271336779, fmeasure=0.09750371984324159), high=Score(precision=0.2020853455223053, recall=0.07117803001814749, fmeasure=0.10001315777178146))
# Rougel
# AggregateScore(low=Score(precision=0.33932414254185966, recall=0.12412901309745183, fmeasure=0.17312396335131125), mid=Score(precision=0.3436536132963405, recall=0.12590632844939265, fmeasure=0.1752332755667736), high=Score(precision=0.3479917221890716, recall=0.12762457211183778, fmeasure=0.17733449822699351))
# Rougelsum
# AggregateScore(low=Score(precision=0.3396202971098099, recall=0.12438635886696942, fmeasure=0.17343588316800113), mid=Score(precision=0.3439076550192912, recall=0.12597060093821344, fmeasure=0.17530572757527332), high=Score(precision=0.3481668687689851, recall=0.12766591514471226, fmeasure=0.17741174191581616))
#
# -----Results for Epoch 2 Run 10 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.5175264393226944, recall=0.2130751463947001, fmeasure=0.28762693629767755), mid=Score(precision=0.522650842021271, recall=0.2157392576782956, fmeasure=0.29034755977369014), high=Score(precision=0.5273308666774411, recall=0.21860624589444336, fmeasure=0.29322136083415135))
# Rouge2
# AggregateScore(low=Score(precision=0.19064494354254266, recall=0.07434709363270689, fmeasure=0.10157341556687693), mid=Score(precision=0.19542711981421018, recall=0.07672030099029686, fmeasure=0.10442556074466793), high=Score(precision=0.2010006440208373, recall=0.07895578394047176, fmeasure=0.10724308498367359))
# Rougel
# AggregateScore(low=Score(precision=0.33161718677115004, recall=0.13332309129653924, fmeasure=0.18089540360964573), mid=Score(precision=0.3356802220177888, recall=0.13516312799710095, fmeasure=0.18280534659219377), high=Score(precision=0.3402574305518, recall=0.13721889454367325, fmeasure=0.1851618229575313))
# Rougelsum
# AggregateScore(low=Score(precision=0.33148892288295767, recall=0.13344580139427292, fmeasure=0.18082230868413074), mid=Score(precision=0.3358291566206816, recall=0.13527456257062337, fmeasure=0.18297491217433542), high=Score(precision=0.34020849159441896, recall=0.13734543618056755, fmeasure=0.1851524092385159))
#
# -----Results for Epoch 2 Run 15 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.4963080826232317, recall=0.2034677404159446, fmeasure=0.27399817527663833), mid=Score(precision=0.5003958722317208, recall=0.20592933211692502, fmeasure=0.2764946177022295), high=Score(precision=0.5044218831672055, recall=0.20858692268945353, fmeasure=0.2790703320495403))
# Rouge2
# AggregateScore(low=Score(precision=0.1540924923178833, recall=0.05963716239011251, fmeasure=0.08118616410408003), mid=Score(precision=0.15855178113527468, recall=0.061421210608499796, fmeasure=0.0835617576037862), high=Score(precision=0.1628754714363834, recall=0.06335419763086483, fmeasure=0.08605601337706063))
# Rougel
# AggregateScore(low=Score(precision=0.3107794413433575, recall=0.12385264720387368, fmeasure=0.1678890465516566), mid=Score(precision=0.31460667837261375, recall=0.12557655592645156, fmeasure=0.1696737142875518), high=Score(precision=0.31865636114031787, recall=0.1271682619736814, fmeasure=0.1714981860380055))
# Rougelsum
# AggregateScore(low=Score(precision=0.3110780364396614, recall=0.12401897454036093, fmeasure=0.16797314172586897), mid=Score(precision=0.31481165489880475, recall=0.12565638224951772, fmeasure=0.16981007343866839), high=Score(precision=0.31855989229266807, recall=0.12731462217151276, fmeasure=0.17153353743601082))
#
# -----Results for Epoch 2 Run 20 Tuned LED Model-----
# Rouge1
# AggregateScore(low=Score(precision=0.47993194649769505, recall=0.21210800369406363, fmeasure=0.2783672083321383), mid=Score(precision=0.48411756126300637, recall=0.2145992951428414, fmeasure=0.2808761396076004), high=Score(precision=0.4887674950924891, recall=0.2172986550984764, fmeasure=0.28360859100082036))
# Rouge2
# AggregateScore(low=Score(precision=0.14757888350623205, recall=0.06189698296279488, fmeasure=0.08220735772411832), mid=Score(precision=0.1520310981721133, recall=0.06377131869557111, fmeasure=0.08450956484684168), high=Score(precision=0.15620356324684126, recall=0.06567922785264399, fmeasure=0.08683057163729509))
# Rougel
# AggregateScore(low=Score(precision=0.2965468171433327, recall=0.12699081666712606, fmeasure=0.16760628869807304), mid=Score(precision=0.30003083240658845, recall=0.1286625085910327, fmeasure=0.16954574492683994), high=Score(precision=0.30434011399833455, recall=0.1304050154805035, fmeasure=0.17151678418042957))
# Rougelsum
# AggregateScore(low=Score(precision=0.2966180421888576, recall=0.12696574338684596, fmeasure=0.16768296114251666), mid=Score(precision=0.3001573354141831, recall=0.1287056880103137, fmeasure=0.16962749079498002), high=Score(precision=0.30407187922790097, recall=0.13053129158291113, fmeasure=0.17170169546749847))

# %% [markdown]
# ## Sandbox

# %%
gc.collect()
# Out:
# 0
